# %%
#import necessary libraries
import pandas as pd
import numpy as np

# %%
#import the provided dataset into motebook
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e875ac92-fbff-4200-b756-5dadd93fe88d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e875ac92-fbff-4200-b756-5dadd93fe88d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#convert dataset into dataframe
df = pd.read_csv("FoodBalanceSheets (1).csv", encoding = "latin-1")

# %%
#view data
df.head(10)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df['Y2014']. isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60938    False
# 60939    False
# 60940    False
# 60941    False
# 60942    False
# Name: Y2014, Length: 60943, dtype: bool

# %%
#the total number of missing data in 2014
total_missing_data = df['Y2014'].isnull().sum()
print("Total number of missing data in 'Y2014':", total_missing_data)
# Out:
# Total number of missing data in 'Y2014': 1589

# %%
#Select columns ‘Y2017’ and ‘Area’
result = df[['Y2017', 'Area']]

#Perform a groupby operation on ‘Area’
result = df[['Y2017', 'Area']].groupby('Area').sum()

#Areas with the highest sum in 2017
area_highest_sum = result.idxmax()[0]
highest_sum = result.max()[0]

print("Area with the highest sum in 2017:", area_highest_sum)
print("Highest sum in 2017:", highest_sum)
# Out:
# Area with the highest sum in 2017: Nigeria
# Highest sum in 2017: 1483268.23

# %%
#Select columns ‘Y2017’ and ‘Area’ and Perform a groupby operation on ‘Area’
result = df[['Y2017', 'Area']].groupby('Area').sum()

#Which of these Areas had the 7th lowest sum in 2017?
sorted = result.sort_values(by='Y2017')
area_with_7th_lowest_sum = sorted.index[6]

print("Area with the 7th lowest sum in 2017:", area_with_7th_lowest_sum)

sorted = sort_
area_7th_lowest_sum = result.idxmin()[0]

print("Area with the 7th lowest sum in 2017:", area_7th_lowest_sum)
# Out:
# Area with the 7th lowest sum in 2017: Guinea-Bissau

# %%
# Calculate the mean and standard deviation
mean_2017 = df['Y2017'].mean()
std_2017 = df['Y2017'].std()


# Round the mean and standard deviation to 2 decimal places
mean_2017 = round(mean_2017, 2)
std_2017 = round(std_2017, 2)

print("Mean of Y2017:", mean_2017)
print("std of Y2017:", std_2017)
# Out:
# Mean of Y2017: 140.92
# std of Y2017: 1671.86

# %%
# What is the total sum of Wine produced in 2015 and 2018 respectively?

wine_production = df[['Y2015', 'Y2018']].groupby('Item').sum()

# %%
#What is the total number of unique countries in the dataset?

total_countries = df['Area'].nunique()
print("Total number of unique countries:", total_countries)
# Out:
# Total number of unique countries: 49
